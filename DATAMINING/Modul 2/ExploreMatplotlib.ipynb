# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, color = 'r', ls = '--', linewidth = '5')
plt.show()

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
xpoint = np.array([7,10,11,14,17,17,19,20])
ypoints = np.array([11,5,15,2,1,11,4,20])

plt.plot(xpoint, ypoints, marker = '*', ms = 15, mec = 'blue', mfc = 'yellow')
plt.show()

# %%
xpoint = np.array([7,10,11,14,17,17,19,20])
ypoints = np.array([11,5,15,2,1,11,4,20])

plt.plot(xpoint,ypoints, color = 'y', ls = '-', linewidth = '5')
plt.show()

# %%
x1 = np.array([7,10,11,14,17,17,19,20])
y1 = np.array([11,5,15,2,1,11,4,20])
x2 = x1.copy() 
y2= y1.copy() 
y2 +=1
x3 = x1.copy()
x3 +=2
y3 = x1.copy()
plt.plot(x1, y1,color ='b', lw = 3)
plt.plot(x2, y2,color ='r', lw = 3)
plt.plot(x3, y3,color ='y', lw = 3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
x1 = np.array([7,10,11,14,17,17,19,20])
y1 = np.array([11,5,15,2,1,11,4,20])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Latihan", fontdict = font1)
plt.xlabel("Nilai Mendatar", fontdict = font2)
plt.ylabel("Nilai vertikal", fontdict = font1)

plt.plot(x, y)
plt.show()

# %%
plt.subplot(2, 2, 1)
x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])

plt.plot(x,y)

plt.subplot(2, 2, 2)
x1 = x+1
y1 = y+1            

plt.plot(x1,y1)

plt.subplot(2, 2, 3)
x2 = x1+1
y2 = y1+1            

plt.plot(x2,y2)

plt.show()

# %%
fig, axes = plt.subplots(3,2,figsize = (8,5)) 

axes[2,1].plot(np.array([0,1,2,3]), ([10,20,30,40]))

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])
plt.scatter(x, y, color = 'hotpink')

x1 = x
y2 = y+1
plt.scatter(x1, y2, color = 'blue')

plt.show()
